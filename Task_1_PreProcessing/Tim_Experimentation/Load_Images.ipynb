# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from PIL import Image
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Project directory on Google Drive
project_path = '/content/drive/MyDrive/NN_Guessing_Game'

# --- Helper Functions ---
def load_image(image_path):
    image = Image.open(image_path)
    normalize_image = transforms.Compose([transforms.Grayscale(), transforms.ToTensor(), transforms.Normalize((0.1307), (0.3081,))])
    show_image = transforms.Compose([transforms.Grayscale(), transforms.ToTensor(), transforms.Normalize((0.1307), (0.3081,))])

    image_to_show = show_image(image)
    image_normalized = normalize_image(image)
    image_normalized = image_normalized.view(-1, 28 * 28)
    return image_normalized
# Out:
# Starting Processes
# Create Neural Network (nn) OR Guess Number (gn)?
# > nn
# Creating Neural Network
# Loading training set
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 15.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 476kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.44MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 11.0MB/s]
# Loading data test set
# Creating Neural Network
# Beginning Training
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.295546
# Train Epoch: 0 [2000/60000 (3%)]	Loss: 2.169513
# Train Epoch: 0 [4000/60000 (7%)]	Loss: 1.860871
# Train Epoch: 0 [6000/60000 (10%)]	Loss: 1.266698
# Train Epoch: 0 [8000/60000 (13%)]	Loss: 0.780442
# Train Epoch: 0 [10000/60000 (17%)]	Loss: 0.570347
# Train Epoch: 0 [12000/60000 (20%)]	Loss: 0.579665
# Train Epoch: 0 [14000/60000 (23%)]	Loss: 0.498819
# Train Epoch: 0 [16000/60000 (27%)]	Loss: 0.508517
# Train Epoch: 0 [18000/60000 (30%)]	Loss: 0.436761
# Train Epoch: 0 [20000/60000 (33%)]	Loss: 0.270302
# ...
